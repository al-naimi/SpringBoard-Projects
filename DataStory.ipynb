# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
my_dataset = pd.read_csv ('C:\\Users\\omar_\\Desktop\\Springboard DataScience\\Capstone Project\\my 1st project\\project progress\\Data_SecondarySource\\Hospital-Readmission.csv')

# %%
my_dataset.head (3)
# Out:
#    RowNumber  PatientInsuranceNO.   Surname  SES-CreditScore HospitalLocation  \
# 0          1             15634602  Hargrave              619        Manhattan
# 1          2             15647311      Hill              608     StatenIsland
# 2          3             15619304      Onio              502        Manhattan
#
#    Gender  Age  AdmisionPeriod/day  PreviousExpenses  \
# 0  Female   42                   2              0.00
# 1  Female   41                   1          83807.86
# 2  Female   42                   8         159660.80
#
#    NumOfPrevious admissions  HealthInsurance  RegularCheckup  \
# 0                         1                1               1
# 1                         1                0               1
# 2                         3                1               0
#
#    EstimatedExpenses  Readmited
# 0          101348.88          1
# 1          112542.58          0
# 2          113931.57          1

# %% [markdown]
# A/B test visualization
# 1) counting number of readmitted patients per whole data set
# 2) counting number of readmitted patients per gender
# 3) counting number of readmitted patients per hospital location
# 4) percent of readmitted patients for the three datasets above

# %%
plt.style.use ('ggplot')
readmitedc = my_dataset ["Readmited"].value_counts ()
hospitalc = my_dataset ["HospitalLocation"].value_counts()
print (readmitedc, hospitalc)
# Out:
# 0    7963
# 1    2037
# Name: Readmited, dtype: int64 Manhattan       5014
# Bronx           2509
# StatenIsland    2477
# Name: HospitalLocation, dtype: int64

# %%
readmitedc.plot(kind = 'barh')

# %% [markdown]
# Total readmission is 20% which is a big percent.

# %%
hospitalc.plot (kind = 'barh')

# %% [markdown]
# Manhattan hospital patient no. is about double the no. of Bronx and Staten Island

# %%
my_dataset ['AdmisionPeriod/day'].plot ('hist')

# %% [markdown]
# Admission for 10 days is the highest among other numbers, and for 1 day is the lowes. All other days are equal.
# The 10 days admission might indicate that most admitted patients have serious conditions.

# %%
my_dataset ['NumOfPrevious admissions'].plot (kind = 'hist')

# %%
my_dataset.plot.scatter (x = 'PreviousExpenses', y= 'EstimatedExpenses' )

# %% [markdown]
# The scatter plot above shows that there is no clear linear or non-linear correlation between Previous expenses and outcome expenses.
