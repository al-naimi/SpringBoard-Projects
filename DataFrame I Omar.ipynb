# %%
import pandas as pd
# hospital = pd.read_csv ('hospital.csv', index_col = "HospitalLocation", usecols= ['Gender', 'Age', 'HospitalLocation'])
hospital = pd.read_csv ('hospital.csv')
hospital.head ()
# Out:
#    RowNumber  PatientInsuranceNO.   Surname  SES-CreditScore HospitalLocation  \
# 0          1             15634602  Hargrave              619        Manhattan
# 1          2             15647311      Hill              608     StatenIsland
# 2          3             15619304      Onio              502        Manhattan
# 3          4             15701354      Boni              699        Manhattan
# 4          5             15737888  Mitchell              850     StatenIsland
#
#    Gender  Age  AdmisionPeriod/day  PreviousExpenses  \
# 0  Female   42                   2              0.00
# 1  Female   41                   1          83807.86
# 2  Female   42                   8         159660.80
# 3  Female   39                   1              0.00
# 4  Female   43                   2         125510.82
#
#    NumOfPrevious admissions  HealthInsurance  RegularCheckup  \
# 0                         1                1               1
# ...

# %%
select = ['Gender', 'Age', 'HospitalLocation']
hospital1 = hospital [select]

# %%
hospital.index
hospital.values
hospital.dtypes
hospital.info ()
hospital.shape
hospital.columns
hospital.axes
hospital.style
hospital.sample ()
hospital.set_index ('Surname', append= False).head (3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# RowNumber                   10000 non-null int64
# PatientInsuranceNO.         10000 non-null int64
# Surname                     10000 non-null object
# SES-CreditScore             10000 non-null int64
# HospitalLocation            10000 non-null object
# Gender                      10000 non-null object
# Age                         10000 non-null int64
# AdmisionPeriod/day          10000 non-null int64
# PreviousExpenses            10000 non-null float64
# NumOfPrevious admissions    10000 non-null int64
# HealthInsurance             10000 non-null int64
# RegularCheckup              10000 non-null int64
# EstimatedExpenses           10000 non-null float64
# Readmited                   10000 non-null int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB
#           RowNumber  PatientInsuranceNO.  SES-CreditScore HospitalLocation  \
# Surname
# ...

# %%
# hospital.get ('Age')
# hospital.get_value (col= 'Age', index= 1)
hospital.get_values ()
hospital.get_ftype_counts ()
hospital.get_dtype_counts ()
hospital.value_counts ()
hospital ['Age'].value_counts ()
# Out:
# float64    2
# int64      9
# object     3
# dtype: int64

# %%
hospital.sum(axis= "columns"). head(3)  # hospital.sum(axis= 1)
# hospital.sum(axis = "rows")     # hospital.sum(axis= 0)
# Out:
# 0    15736618.88
# 1    15844315.44
# 2    15893456.37
# dtype: float64

# %%
pa = hospital.PreviousExpenses / hospital ["AdmisionPeriod/day"]
hospital ["pa"] = pa

# hospital.insert (2, column= "xy", value = pa)

hospital.head ()
# Out:
#    RowNumber  PatientInsuranceNO.        xy        ap   Surname  \
# 0          1             15634602      0.00      0.00  Hargrave
# 1          2             15647311  83807.86  83807.86      Hill
# 2          3             15619304  19957.60  19957.60      Onio
# 3          4             15701354      0.00      0.00      Boni
# 4          5             15737888  62755.41  62755.41  Mitchell
#
#    SES-CreditScore HospitalLocation  Gender  Age  AdmisionPeriod/day  \
# 0              619        Manhattan  Female   42                   2
# 1              608     StatenIsland  Female   41                   1
# 2              502        Manhattan  Female   42                   8
# 3              699        Manhattan  Female   39                   1
# 4              850     StatenIsland  Female   43                   2
#
#    PreviousExpenses  NumOfPrevious admissions  HealthInsurance  \
# 0              0.00                         1                1
# ...

# %%
hospital ['xy']. add (10)  # hospital ['xy'] + 10
hospital ['xy'].div (10)   #  hospital ['xy'] / 10
hospital ['xy'].mul (10)  #  hospital ['xy'] * 10
hospital ['xy'].sub (10).head(1) #  hospital ['xy'] - 10
# Out:
# 0   -10.0
# Name: xy, dtype: float64

# %%
hospital.dropna (how = "all", subset = ['Age', 'xy'], inplace = True)

# %%
hospital.fillna (0)
hospital ['Age'].fillna (0).head (2)
# Out:
# 0    42
# 1    41
# Name: Age, dtype: int64

# %%
hospital ['PreviousExpenses'].astype ('int').head(2)
# Out:
# 0        0
# 1    83807
# Name: PreviousExpenses, dtype: int32

# %%
hospital ['HospitalLocation'].unique ()
hospital ['HospitalLocation'].astype ('category').head (4)
# Out:
# 0       Manhattan
# 1    StatenIsland
# 2       Manhattan
# 3       Manhattan
# Name: HospitalLocation, dtype: category
# Categories (3, object): [Bronx, Manhattan, StatenIsland]

# %%
hospital.sort_values (['Age', 'xy'], ascending = [True, False], na_position= 'last').tail ()
# Out:
#       RowNumber  PatientInsuranceNO.             xy             ap  Surname  \
# 3531       3532             15653251   10984.173750   10984.173750   Hickey
# 3033       3034             15578006       0.000000       0.000000      Yao
# 2458       2459             15813303       0.000000       0.000000  Rearick
# 6759       6760             15660878  126076.240000  126076.240000    T'ien
# 6443       6444             15764927   40504.436667   40504.436667   Rogova
#
#       SES-CreditScore HospitalLocation  Gender  Age  AdmisionPeriod/day  \
# 3531              408        Manhattan  Female   84                   8
# 3033              787        Manhattan  Female   85                  10
# 2458              513     StatenIsland    Male   88                  10
# 6759              705        Manhattan    Male   92                   1
# 6443              753        Manhattan    Male   92                   3
#
#       PreviousExpenses  NumOfPrevious admissions  HealthInsurance  \
# ...

# %%
# optimize memory    date-time, .astype ('int'), ('bool'), ('category') 

# df = pd.read_csv("employees.csv", parse_dates = ["Start Date", "Last Login Time"])
# df ['date time']= pd.to_datetime (df ['date time'])
#df["Senior Management"] = df["Senior Management"].astype("bool")
#df["Gender"] = df["Gender"].astype("category")

# %%
# filtering based on 1 or more conditions

hospital ['Gender'] == 'Male'
#hospital [hospital ['Gender'] == 'Male'].head ()
filter = hospital ['Gender'] == 'Male'
hospital [filter]. head (1)
# Out:
#    RowNumber  PatientInsuranceNO.          xy          ap Surname  \
# 5          6             15574012  14219.4725  14219.4725     Chu
#
#    SES-CreditScore HospitalLocation Gender  Age  AdmisionPeriod/day  \
# 5              645     StatenIsland   Male   44                   8
#
#    PreviousExpenses  NumOfPrevious admissions  HealthInsurance  \
# 5         113755.78                         2                1
#
#    RegularCheckup  EstimatedExpenses  Readmited p/a          pa
# 5               0          149756.71          1      14219.4725

# %%
filter = hospital ['Gender'] == 'Male'
filter2 = hospital ['HospitalLocation'] == 'Bronx'
hospital [filter | filter2]. head (2)   # hospital [filter & filter2] | or
# hospital [(filter & filter1) | filter2]
# Out:
#    RowNumber  PatientInsuranceNO.          xy          ap   Surname  \
# 5          6             15574012  14219.4725  14219.4725       Chu
# 6          7             15592531      0.0000      0.0000  Bartlett
#
#    SES-CreditScore HospitalLocation Gender  Age  AdmisionPeriod/day  \
# 5              645     StatenIsland   Male   44                   8
# 6              822        Manhattan   Male   50                   7
#
#    PreviousExpenses  NumOfPrevious admissions  HealthInsurance  \
# 5         113755.78                         2                1
# 6              0.00                         2                1
#
#    RegularCheckup  EstimatedExpenses  Readmited p/a          pa
# 5               0          149756.71          1      14219.4725
# 6               1           10062.80          0          0.0000

# %%
hospital ['HospitalLocation'].isin (['Bronx', 'StatenIsland'])
selection = hospital ['HospitalLocation'].isin (['Bronx', 'StatenIsland'])
hospital [selection]. head ()
# Out:
#     RowNumber  PatientInsuranceNO.          xy          ap   Surname  \
# 1           2             15647311  83807.8600  83807.8600      Hill
# 4           5             15737888  62755.4100  62755.4100  Mitchell
# 5           6             15574012  14219.4725  14219.4725       Chu
# 7           8             15656148  28761.6850  28761.6850    Obinna
# 11         12             15737173      0.0000      0.0000   Andrews
#
#     SES-CreditScore HospitalLocation  Gender  Age  AdmisionPeriod/day  \
# 1               608     StatenIsland  Female   41                   1
# 4               850     StatenIsland  Female   43                   2
# 5               645     StatenIsland    Male   44                   8
# 7               376            Bronx  Female   29                   4
# 11              497     StatenIsland    Male   24                   3
#
#     PreviousExpenses  NumOfPrevious admissions  HealthInsurance  \
# ...

# %%
# df ['Team'].isnull ()
# df ['Team'].notnull ()
# df ['Salary'].between (5000, 60000)
# df ['Date'].between ('1-1-2000', '1-1-2005')
# df ['Name'].duplicated (keep = False)  # ~ df ['Name'].duplicated (keep = False) to get the unique values (never been duplicated)
# df.drop_duplicates (subset = [FirstName'], keep = 'first')

# %%
#df ['Team']. unique (dropna = False) will retun even NaN
# df.set_index ('Name', inplace = True)    the column Name will be bold
# df.reset_index () important step befor assigning different index. otherwise will overwrite the existed index

# %%
# hospital.set_index ('Surname', inplace = True)
# hospital.loc ['Hill']
# hospital.loc ['Hill' : 'Onion'] will return all indicies from Hill to Onion included
# hospital.loc ['Hill' : ]   # hospital.loc [ : 'Onion']
# hospital.loc [['Hill', 'Onion']]  will select only these two indicies
# if one of them is not existed, will give NaN for that one (not error be careful with multiple selection)
# "ABC" in hospital.index # check that index if it is in the table

hospital.iloc [[1, 3, 10]]
# Out:
#          RowNumber  PatientInsuranceNO.            xy            ap  \
# Surname
# Hill             2             15647311  83807.860000  83807.860000
# Boni             4             15701354      0.000000      0.000000
# Bearce          11             15767821  17002.786667  17002.786667
#
#          SES-CreditScore HospitalLocation  Gender  Age  AdmisionPeriod/day  \
# Surname
# Hill                 608     StatenIsland  Female   41                   1
# Boni                 699        Manhattan  Female   39                   1
# Bearce               528        Manhattan    Male   31                   6
#
#          PreviousExpenses  NumOfPrevious admissions  HealthInsurance  \
# Surname
# Hill             83807.86                         1                0
# Boni                 0.00                         2                0
# Bearce          102016.72                         2                0
#
#          RegularCheckup  EstimatedExpenses  Readmited p/a            pa
# ...
