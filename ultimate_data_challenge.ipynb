# %%
import pandas as pd
import json # if you cannot pd.read_json, import json library and first open or load the file as json file using the code below

# In order to import the dataset as pandas dataframe, first open the file and load it as json file.

with open('ultimate_data_challenge.json') as f:
   dataset = json.load(f)

# %%
dataset = pd.DataFrame(eval("dataset"))  # use eval to prevent (ValueError: DataFrame constructor not properly called!)
# this error occurs because of "providing a string representation of a dict to the DataFrame constructor, and not a dict itself.

dataset.head ()
# Out:
#    avg_dist  avg_rating_by_driver  avg_rating_of_driver  avg_surge  \
# 0      3.67                   5.0                   4.7       1.10
# 1      8.26                   5.0                   5.0       1.00
# 2      0.77                   5.0                   4.3       1.00
# 3      2.36                   4.9                   4.6       1.14
# 4      3.13                   4.9                   4.4       1.19
#
#              city last_trip_date    phone signup_date  surge_pct  \
# 0  King's Landing     2014-06-17   iPhone  2014-01-25       15.4
# 1         Astapor     2014-05-05  Android  2014-01-29        0.0
# 2         Astapor     2014-01-07   iPhone  2014-01-06        0.0
# 3  King's Landing     2014-06-29   iPhone  2014-01-10       20.0
# 4      Winterfell     2014-03-15  Android  2014-01-27       11.8
#
#    trips_in_first_30_days  ultimate_black_user  weekday_pct
# 0                       4                 True         46.2
# ...
